# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
#open dataset and add paths to array
import pathlib
paths =[]
for path in pathlib.Path("Dataset\mask_weared_incorrect").iterdir():
    #print(path)
    paths.append(path)
for path in pathlib.Path("Dataset\with_mask").iterdir():
    #print(path)
    paths.append(path)
for path in pathlib.Path("Dataset\without_mask").iterdir():
    #print(path)
    paths.append(path)

#check length of paths array to see if all data was copied(8982 files)    
print(len(paths))
# Out:
# 8982

# %%
#incorrect_mask = list(paths.glob('mask_weared_incorrect/*'))
PIL.Image.open(paths[0])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=128x128 at 0x12FDA689BE0>

# %%
#define parameters for the loader
batch_size = 32
img_height = 128
img_width = 128
directory = "Dataset/"

# %%
#create training dataset
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
  directory,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 8982 files belonging to 3 classes.
# Using 7186 files for training.

# %%
#create test dataset
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
  directory,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 8982 files belonging to 3 classes.
# Using 1796 files for validation.

# %%
#print the class name
class_names = train_dataset.class_names
print(class_names)
# Out:
# ['mask_weared_incorrect', 'with_mask', 'without_mask']

# %%
#configure for better preformance
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_dataset = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8c16646dff2a> in <module>
#       2 AUTOTUNE = tf.data.AUTOTUNE
#       3
# ----> 4 train_dataset = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
#       5 test_dataset = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
#
# NameError: name 'train_ds' is not defined

# %%
#Standardize the images ideal to neural network
rescale_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
#create the model
number_classes = 3

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(number_classes)
])

# %%
#compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_4 (Rescaling)      (None, 128, 128, 3)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 128, 16)      448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               2097280
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 2,121,251
# Trainable params: 2,121,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train the model
epochs=10
history = model.fit(
  train_dataset,
  validation_data=test_dataset,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 225/225 [==============================] - 37s 135ms/step - loss: 0.3259 - accuracy: 0.8688 - val_loss: 0.2064 - val_accuracy: 0.9293
# Epoch 2/10
# 225/225 [==============================] - 30s 133ms/step - loss: 0.1404 - accuracy: 0.9513 - val_loss: 0.1653 - val_accuracy: 0.9449
# Epoch 3/10
# 225/225 [==============================] - 29s 130ms/step - loss: 0.0958 - accuracy: 0.9676 - val_loss: 0.1570 - val_accuracy: 0.9521
# Epoch 4/10
# 225/225 [==============================] - 29s 130ms/step - loss: 0.0681 - accuracy: 0.9755 - val_loss: 0.1032 - val_accuracy: 0.9655
# Epoch 5/10
# 225/225 [==============================] - 29s 130ms/step - loss: 0.0612 - accuracy: 0.9802 - val_loss: 0.1008 - val_accuracy: 0.9660
# Epoch 6/10
# 225/225 [==============================] - 29s 130ms/step - loss: 0.0334 - accuracy: 0.9879 - val_loss: 0.0991 - val_accuracy: 0.9705
# Epoch 7/10
# 225/225 [==============================] - 30s 132ms/step - loss: 0.0169 - accuracy: 0.9958 - val_loss: 0.2600 - val_accuracy: 0.9104
# Epoch 8/10
# 225/225 [==============================] - 29s 131ms/step - loss: 0.0406 - accuracy: 0.9859 - val_loss: 0.0679 - val_accuracy: 0.9822
# Epoch 9/10
# 225/225 [==============================] - 29s 130ms/step - loss: 0.0189 - accuracy: 0.9929 - val_loss: 0.0853 - val_accuracy: 0.9766
# Epoch 10/10
# 225/225 [==============================] - 30s 131ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.1638 - val_accuracy: 0.9465

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
